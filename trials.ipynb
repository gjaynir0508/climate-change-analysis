# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/GlobalTemperatures.csv')
df_city = pd.read_csv('datasets/GlobalLandTemperaturesByCity.csv')
df_country = pd.read_csv('datasets/GlobalLandTemperaturesByCountry.csv')
df_major = pd.read_csv('datasets/GlobalLandTemperaturesByMajorCity.csv')
df_state = pd.read_csv('datasets/GlobalLandTemperaturesByState.csv')

# %%
df['dt'] = pd.to_datetime(df['dt'])
df_city['dt'] = pd.to_datetime(df_city['dt'])
df_country['dt'] = pd.to_datetime(df_country['dt'])
df_major['dt'] = pd.to_datetime(df_major['dt'])
df_state['dt'] = pd.to_datetime(df_state['dt'])

# %%
df = df.set_index('dt')
df_city = df_city.set_index('dt')
df_country = df_country.set_index('dt')
df_major = df_major.set_index('dt')
df_state = df_state.set_index('dt')

# %%
df
# Out:
#             LandAverageTemperature  LandAverageTemperatureUncertainty  \
# dt
# 1750-01-01                   3.034                              3.574
# 1750-02-01                   3.083                              3.702
# 1750-03-01                   5.626                              3.076
# 1750-04-01                   8.490                              2.451
# 1750-05-01                  11.573                              2.072
# ...                            ...                                ...
# 2015-08-01                  14.755                              0.072
# 2015-09-01                  12.999                              0.079
# 2015-10-01                  10.801                              0.102
# 2015-11-01                   7.433                              0.119
# 2015-12-01                   5.518                              0.100
#
#             LandMaxTemperature  LandMaxTemperatureUncertainty  \
# dt
# 1750-01-01                 NaN                            NaN
# 1750-02-01                 NaN                            NaN
# 1750-03-01                 NaN                            NaN
# 1750-04-01                 NaN                            NaN
# 1750-05-01                 NaN                            NaN
# ...                        ...                            ...
# 2015-08-01              20.699                          0.110
# 2015-09-01              18.845                          0.088
# 2015-10-01              16.450                          0.059
# 2015-11-01              12.892                          0.093
# 2015-12-01              10.725                          0.154
#
#             LandMinTemperature  LandMinTemperatureUncertainty  \
# dt
# 1750-01-01                 NaN                            NaN
# 1750-02-01                 NaN                            NaN
# 1750-03-01                 NaN                            NaN
# 1750-04-01                 NaN                            NaN
# 1750-05-01                 NaN                            NaN
# ...                        ...                            ...
# 2015-08-01               9.005                          0.170
# 2015-09-01               7.199                          0.229
# 2015-10-01               5.232                          0.115
# 2015-11-01               2.157                          0.106
# 2015-12-01               0.287                          0.099
#
#             LandAndOceanAverageTemperature  \
# dt
# 1750-01-01                             NaN
# 1750-02-01                             NaN
# 1750-03-01                             NaN
# 1750-04-01                             NaN
# 1750-05-01                             NaN
# ...                                    ...
# 2015-08-01                          17.589
# 2015-09-01                          17.049
# 2015-10-01                          16.290
# 2015-11-01                          15.252
# 2015-12-01                          14.774
#
#             LandAndOceanAverageTemperatureUncertainty
# dt
# 1750-01-01                                        NaN
# 1750-02-01                                        NaN
# 1750-03-01                                        NaN
# 1750-04-01                                        NaN
# 1750-05-01                                        NaN
# ...                                               ...
# 2015-08-01                                      0.057
# 2015-09-01                                      0.058
# 2015-10-01                                      0.062
# 2015-11-01                                      0.063
# 2015-12-01                                      0.062
#
# [3192 rows x 8 columns]

# %%
# Exploratory Data Analysis
# Global Temperatures
plt.figure(figsize=(15, 5))
df['LandAverageTemperature'].plot()
plt.show()

# Global Land Temperatures By City
plt.figure(figsize=(15, 5))
df['LandAverageTemperature'].resample('A').mean().plot()
plt.show()

# Global Land Temperatures By City
plt.figure(figsize=(15, 5))
df_city['AverageTemperature'].resample('A').mean().plot()
plt.show()

# Global Land Temperatures By Country
plt.figure(figsize=(15, 5))
df_country['AverageTemperature'].resample('A').mean().plot()

# Global Land Temperatures By Major City
plt.figure(figsize=(15, 5))
df_major['AverageTemperature'].resample('A').mean().plot()
# Out:
# <AxesSubplot: xlabel='dt'>

# %% [markdown]
# ## Trial using Pola.rs
# Pola.rs is way faster upto 4x faster than Pandas

# %%
import polars as pl

# %%
df_pl = pl.read_csv('datasets/GlobalTemperatures.csv', try_parse_dates=True)
df_city_pl = pl.read_csv('datasets/GlobalLandTemperaturesByCity.csv', try_parse_dates=True)
df_country_pl = pl.read_csv('datasets/GlobalLandTemperaturesByCountry.csv', try_parse_dates=True)
df_major_pl = pl.read_csv('datasets/GlobalLandTemperaturesByMajorCity.csv', try_parse_dates=True)
df_state_pl = pl.read_csv('datasets/GlobalLandTemperaturesByState.csv', try_parse_dates=True)

# %%
df_pl
# Out:
# shape: (3_192, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ dt        ┆ LandAvera ┆ LandAvera ┆ LandMaxTe ┆ … ┆ LandMinTe ┆ LandMinTe ┆ LandAndOc ┆ LandAndO │
# │ ---       ┆ geTempera ┆ geTempera ┆ mperature ┆   ┆ mperature ┆ mperature ┆ eanAverag ┆ ceanAver │
# │ date      ┆ ture      ┆ tureUncer ┆ ---       ┆   ┆ ---       ┆ Uncertain ┆ eTemperat ┆ ageTempe │
# │           ┆ ---       ┆ taint…    ┆ str       ┆   ┆ str       ┆ ty        ┆ ure       ┆ ratureUn │
# │           ┆ f64       ┆ ---       ┆           ┆   ┆           ┆ ---       ┆ ---       ┆ …        │
# │           ┆           ┆ f64       ┆           ┆   ┆           ┆ str       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1750-01-0 ┆ 3.034     ┆ 3.574     ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1750-02-0 ┆ 3.083     ┆ 3.702     ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1750-03-0 ┆ 5.626     ┆ 3.076     ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1750-04-0 ┆ 8.49      ┆ 2.451     ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1750-05-0 ┆ 11.573    ┆ 2.072     ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2015-08-0 ┆ 14.755    ┆ 0.072     ┆ 20.699    ┆ … ┆ 9.0049999 ┆ 0.17      ┆ 17.589000 ┆ 0.057    │
# │ 1         ┆           ┆           ┆           ┆   ┆ 99999997  ┆           ┆ 000000002 ┆          │
# │ 2015-09-0 ┆ 12.999    ┆ 0.079     ┆ 18.845    ┆ … ┆ 7.199     ┆ 0.229     ┆ 17.049    ┆ 0.058    │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2015-10-0 ┆ 10.801    ┆ 0.102     ┆ 16.45     ┆ … ┆ 5.2319999 ┆ 0.115     ┆ 16.29     ┆ 0.062    │
# │ 1         ┆           ┆           ┆           ┆   ┆ 99999998  ┆           ┆           ┆          │
# │ 2015-11-0 ┆ 7.433     ┆ 0.119     ┆ 12.892000 ┆ … ┆ 2.157     ┆ 0.106     ┆ 15.252    ┆ 0.063    │
# │ 1         ┆           ┆           ┆ 000000001 ┆   ┆           ┆           ┆           ┆          │
# │ 2015-12-0 ┆ 5.518     ┆ 0.1       ┆ 10.725    ┆ … ┆ 0.2869999 ┆ 0.099     ┆ 14.774    ┆ 0.062    │
# │ 1         ┆           ┆           ┆           ┆   ┆ 999999997 ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_10y_avg = df_pl.sort("dt").group_by_dynamic("dt", every="10y").agg(pl.col("LandAverageTemperature").mean())
df_10y_avg.plot.bar(x="dt", y="LandAverageTemperature")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 df_10y_avg = df_pl.sort("dt").group_by_dynamic("dt", every="10y").agg(pl.col("LandAverageTemperature").mean())
# ----> 2 df_10y_avg.plot.bar(x="dt", y="LandAverageTemperature")
#
# File a:\src\python\Lib\site-packages\hvplot\plotting\core.py:1092, in hvPlotTabular.bar(self, x, y, **kwds)
#    1005 def bar(self, x=None, y=None, **kwds):
#    1006     """
#    1007     A vertical bar plot
#    1008
#    (...)
#    1090     - Wiki: https://en.wikipedia.org/wiki/Bar_chart
#    1091     """
# -> 1092     return self(x, y, kind="bar", **kwds)
#
# File a:\src\python\Lib\site-packages\hvplot\plotting\core.py:96, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      93         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      94         return pn.panel(plot, **panel_dict)
# ---> 96 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File a:\src\python\Lib\site-packages\hvplot\plotting\core.py:1902, in hvPlotTabularPolars._get_converter(self, x, y, kind, **kwds)
#    1899         columns = sorted(columns, key=lambda c: self._data.columns.index(c))
#    1901 if isinstance(self._data, pl.DataFrame):
# -> 1902     data = self._data.select(columns).to_pandas()
#    1903 elif isinstance(self._data, pl.Series):
#    1904     data = self._data.to_pandas()
#
# File a:\src\python\Lib\site-packages\polars\dataframe\frame.py:1710, in DataFrame.to_pandas(self, use_pyarrow_extension_array, **kwargs)
#    1705 if Object in self.dtypes:
#    1706     return self._to_pandas_with_object_columns(
#    1707         use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    1708     )
# -> 1710 return self._to_pandas_without_object_columns(
#    1711     self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    1712 )
#
# File a:\src\python\Lib\site-packages\polars\dataframe\frame.py:1762, in DataFrame._to_pandas_without_object_columns(self, df, use_pyarrow_extension_array, **kwargs)
#    1759     return pd.DataFrame()
#    1761 record_batches = df._df.to_pandas()
# -> 1762 tbl = pa.Table.from_batches(record_batches)
#    1763 if use_pyarrow_extension_array:
#    1764     return tbl.to_pandas(
#    1765         self_destruct=True,
#    1766         split_blocks=True,
#    1767         types_mapper=lambda pa_dtype: pd.ArrowDtype(pa_dtype),
#    1768         **kwargs,
#    1769     )
#
# File a:\src\python\Lib\site-packages\polars\dependencies.py:97, in _LazyModule.__getattr__(self, attr)
#      95 pfx = self._mod_pfx.get(self._module_name, "")
#      96 msg = f"{pfx}{attr} requires {self._module_name!r} module to be installed"
# ---> 97 raise ModuleNotFoundError(msg) from None
#
# ModuleNotFoundError: pa.Table requires 'pyarrow' module to be installed
